# %% [markdown]
# # Variables
# - a variable is a name that you use to store data or a value in memory so that you can use
# it later in your program.
# - It acts like a container that holds some information
# - for example, a number, text, or list —
# - allows you to refer to that data by name instead of writing it directly every
# time.

# %%
45000 * 12 /100

# %%
amount = 38900
rate = 12 /100

amount * rate

# %%
data = 300
print(data) 
data = 870
print(data)

# %%
aman = 300
rohan = 450
print(aman+rohan)

# %%
first name  = "rohan"

# %% [markdown]
# ## Rules for naming variables
# - Variable names can include letters(a-z,A-Z), numbers(0-9), and
# underscores (_).
# - They must start with a letter or underscore, not a number.
# - Variable names are case-sensitive (Name and name are different).
# - Don’t use Python keywords (like if, for, class, etc.) as variable names.

# %%
# print simple interest using variables -  amount , year and interest rate?
# And then show compound interest of same

amount = 12000
interest_rate = 7/100
year = 4

print(amount * interest_rate * year)

# %% [markdown]
# # Arithmetic Operators

# %%
# + , - ,* , / , // , % , **
# BODMAS

# %%
45 + 6

# %% [markdown]
# ## floor division

# %%
print(56/3)
print(56//3)

# %% [markdown]
# ## Mod

# %%
print(10//3)
print(10%3)

print(78//5)
print(78%5)

# %%
# find if 56 is even or odd

print(55%2)

# %%
print(6%12)

# %% [markdown]
# ## Power **

# %%
print(5*2)
print(5**2)
print(5**3)

# %% [markdown]
# # Data Types in python

# %%
a = 56
type(a)

# %%
a = 6.45
type(a)

# %%
a = "hello"
type(a)

# %%
a = 10/2
print(type(a))
print(a)

# %%
a = 10//2
print(type(a))
print(a)

# %%
a = [54,12,8,76]
print(type(a))
print(a)

# %%
45 > 5
# Out:
# True

# %%
a = True
type(a)
# Out:
# bool

# %%
a = None
type(a)
# Out:
# NoneType

# %%
a = 23 + 2j
type(a)
# Out:
# complex

# %%
# what will happen if the data is not in its correct data type?

# %%
a = "15"
print(a+12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 a = "15"
# ----> 2 print(a+12)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "5"
print(a*3)
# Out:
# 555

# %%
a = "hello"
a*4
# Out:
# 'hellohellohellohello'

# %%
first = "Rohan"
last = "kumar"

print(first + last)
print(first + " " + last)
# Out:
# Rohankumar
# Rohan kumar

# %% [markdown]
# # Input
# taking input from the user in runtime

# %%
name = input()
print("Good Morning", name)
# Out:
# Good Morning Kunal

# %%
# take name and age using input msg from the user and print both
name = input("what is your name")
age = input("what is your age")

print("Your name is",name)
print("Your age is",age)
# Out:
# Your name is 78
# Your age is rohan

# %%
# Take two numbers from the user and Print there total 
num1 = input()
num2 = input()

print(num1+num2)
# Out:
# 4523

# %% [markdown]
# # Type casting

# %%
num1 = int(input())
num2 = int(input())

print(num1+num2)
# Out:
# 68

# %%
num = float(input())
print(num)

# %%
int(6.43423)
# Out:
# 6

# %%
# Write a Python program to add two numbers entered by the user.

# %%
# Write a program to calculate the square and cube of a number.

# %%
# Write a program to calculate the area of a rectangle (length × width).

# %%
# Write a program to calculate the area of a circle using radius = 7.

# %%
# Write a program to ﬁnd the average of three numbers.

# %%
# Write a program to convert temperature from Celsius to Fahrenheit.
# F = (C × 9/5) + 32

c = 45
f = c*(9/5) + 32
print(f)
# Out:
# 113.0

# %%
# Write a program to calculate the simple interest (use formula: SI = (P * R * T) / 100).

# %%
# Write a program to calculate the compound interest.

# %%
# Write a program to ﬁnd the square root of a number using exponent operator (**).

# %%
# Write a program to ﬁnd the perimeter of a square and a rectangle.

# %%
# Write a program to check if a number is even or odd.

# %%
# Write a program to swap two values.
rohan = "car"
kartik = "bike"

mohit = rohan
rohan = kartik
kartik = mohit

print("rohan",rohan)
print("Kartik",kartik)
# Out:
# rohan bike
# Kartik car

# %%
# Write a program to swap two values.
rohan = "car"
kartik = "bike"

rohan,kartik = kartik, rohan

print("rohan",rohan)
print("Kartik",kartik)
# Out:
# rohan bike
# Kartik car

# %%
a , b = 50, 12.9

print(a)
print(b)
# Out:
# 50
# 12.9

# %%
name,age,salary = "raohan",34,40000
print(name)
print(age)
print(salary)
# Out:
# raohan
# 34
# 40000

# %%
a = 30
print(type(a))

a = "hello"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # Assignment operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Update the value of A and add 5 to it?
a = 20
a = a+5

print(a)

# %%
# Update the value of A and add 5 to it?
a = 20
a += 5

print(a)

# %% [markdown]
# # Print Function

# %%
print("hello")
# Out:
# hello

# %%
name = "Anil"
print("hello",name)
# Out:
# hello Anil

# %%
# F-string

name = "Anil"
age = 34

print("hello",name ,"Yor age is",age)
print("hello {name} Yor {age} is age")
print()
print(f"Hello {name} Your age is {age}")
# Out:
# hello Anil Yor age is 34
# hello {name} Yor {age} is age
#
# Hello Anil Your age is 34

# %%
# You are three years older than your friend 
friend = 32

# ans - " My age is 35 and my friend's age is 32"

# %%
name = "Rohan"
msg = f"Good morning {name}"

print(msg)
# Out:
# Good morning Rohan

# %%
sales = 6700
rate = 12/100

print(f"discount {rate*sales}")
# Out:
# discount 804.0

# %%
# End

print("hello")
print("bye")
# Out:
# hello
# bye

# %%
print("hello\nbye")
# Out:
# hello
# bye

# %%
print("hello",end="--")
print("bye")
# Out:
# hello--bye

# %%
# sep

print("Rohan","Kumar")
print("Rohan","Kumar","how","are","you",sep="_")
# Out:
# Rohan Kumar
# Rohan_Kumar_how_are_you

# %%
print('i don't want')
# Out:
#   Cell In[12], line 1
#     print('i don't want')
#                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("i don't want")

# %%
print('i don\'t want')
# Out:
# i don't want

# %% [markdown]
# # Comparison (Relational) Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5 == 5
# Out:
# True

# %%
45 <5
# Out:
# False

# %% [markdown]
# # If Function

# %%
# Find if the person can vote or not
age = 34
if age>=18 :
    print("can vote")
else:
    print("can not vote")
# Out:
# can vote

# %% [markdown]
# **Indentation** :
#
# - indentation means adding spaces or tabs at the beginning of a line to deﬁne blocks of code.
# - Unlike many other programming languages (like C or Java) that use { } to mark code blocks
# - Python uses indentation to show which statements belong together.

# %%
# Write a program to check whether a number is positive or negative.
num = int(input("Enter a number"))

if num>0:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
# Write a program to check if a number is even or odd.

# %%
# Write a program to print “Welcome” if the user enters the correct password.
password = "1234"

# %%
# Write a program to check whether a person is eligible to vote (age ≥ 18).

# %%
# Write a program to check if a given number is divisible by 5.

# %%
# Write a program to check if a number is greater than 100 or not.

# %%
# Write a program to check whether a year is a leap year or not.
year = 2100

if year%400 == 0 or (year%4 == 0 and year%100 != 0):
    print("Leap year")
else:
    print("Normal year")
# Out:
# Normal year

# %%
# Write a program to ﬁnd the largest of two numbers.

# %%
# Write a program to check whether a character is a vowel or consonant.

# %%
# Write a program to check whether a person can drive (age ≥ 18).

# %%
# Write a program to check whether a number is divisible by both 3 and 5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
45 >4  and  20==5
# Out:
# False

# %%
45 >4  or  20==5
# Out:
# True

# %%
not 34>100
# Out:
# True
