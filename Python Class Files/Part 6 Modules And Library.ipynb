# %% [markdown]
# # Modules And Library

# %%
import sample

# %%
total(5,4,3,7)

# %%
sample.total(5,4,3,7)

# %%
sample.discount(5600,6.89)

# %%
import sample as s

# %%
s.total(5,8,12)

# %%
from sample import total

# %%
total(4,5,7,3)

# %%
discount(4500,14)

# %%
import time as t

# %%
t.time()

# %%
start = t.time()

# %%
end = t.time()

# %%
end - start

# %%
t.ctime()

# %%
t.ctime().split()

# %%
print("hello")
print("bye")

# %%
print("hello")
t.sleep(3)
print("bye")

# %%
import random as r

# %%
r.randint(1,100)
# Out:
# 48

# %%
a = r.randint(1,100)
a
# Out:
# 40

# %%
r.random()
# Out:
# 0.15732650509426993

# %%
data = ["rohan",'kunal',"mohit","suman"]
r.choice(data)
# Out:
# 'mohit'

# %%
import random as r
import time as t

count = 0
start = t.time()
for i in range(10):
    num1 = r.randint(1,20)
    num2 = r.randint(1,20)
    print(f"what is {num1} + {num2}")
    user = int(input("Ans -"))
    if user == num1+num2:
        count += 1

end = t.time()
print(f"correct ans = {count}/10 and you took {round(end-start,2)} sec.")

# %% [markdown]
# # Welcome to the "Guess My Number" Game!
# In this Python program, you’ll write a simple and fun number guessing game against the
# computer.
# How the Game Works:
# - The computer will randomly select a number between 1 and 100.
# - Your task is to guess the number chosen by the computer.
# - After each guess:
# - If your guess is correct, the computer will congratulate you.
# - If your guess is incorrect, the computer will tell you whether to guess a higher or
# lower number.
# - The computer will keep track of the number of attempts you make.
# - The game will continue until you guess the correct number.
# - Once you find the correct number, the computer will display a congratulatory message
# along with the
# - total number of attempts you took

# %%
import random as r

pc = r.randint(1,100)
user = int(input("Enter your number"))
count = 1

while pc != user:
    if user > pc:
        print("Guess a smaller number")
    else:
        print("Guess a bigger number")
    user = int(input("Enter your number again"))
    count += 1
    
print("You guess the number correct",pc)
print("you took",count,"try")
# Out:
# Enter your number 10
# Guess a bigger number
# Enter your number again 70
# Guess a smaller number
# Enter your number again 40
# Guess a bigger number
# Enter your number again 66
# Guess a smaller number
# Enter your number again 54
# Guess a smaller number
# Enter your number again 47
# Guess a bigger number
# Enter your number again 50
# Guess a bigger number
# Enter your number again 52
# You guess the number correct 52
# you took 8 try
