# %% [markdown]
# # Try and Except
#
# Try to run this code. If an error happens, don't crash the program—instead, do something else.

# %%
# try:
#     Code that might cause an error
# except:
#     Runs only if an error occurs

# %%
10/0

# %%
try:
    print(10 / 0)
except:
    print("An error occurred.")

# %%
try:
    print("Line 1")
    print(10 / 0)
    print("Line 3")
except:
    print("Error!")

# %%
number = int(input("enter a number only"))
# Out:
# enter a number only h
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 number = int(input("enter a number only"))
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
try:
    number = int(input("enter a number only"))
except ValueError:
    print("Please enter a valid number.")

# %%
try:
    num = int(input("Enter number: "))
    print(100 / num)

except ValueError:
    print("You entered text.")

except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Enter number:  0
# Cannot divide by zero.

# %%
try:
    num = int(input("Enter a number: "))
except ValueError:
    print("Invalid input.")
else:
    print("You entered:", num)
# Out:
# Enter a number:  66
# You entered: 66

# %%
try:
    print(10 / 0)
except:
    print("Error")
finally:
    print("Always runs")
# Out:
# Error
# Always runs
