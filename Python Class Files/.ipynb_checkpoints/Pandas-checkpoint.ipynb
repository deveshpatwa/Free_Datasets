# %% [markdown]
# # Pandas Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
s = pd.Series([230,450,980,500,1200])
print(s)

# %%
# Try  +   -    *    /  //   **  %

s * 2

# %% [markdown]
# # Indexing and slicing

# %%
print(s)

# %%
s[2] = 552

# %%
# Negative indexing does not work in the series 
s[-1]

# %%
print(s)

# %%
s[1:4]

# %% [markdown]
# # Name index

# %%
age = pd.Series({"rohan":34,"kunal":78,"kartik":23,"mohit":12,"naman":46})
print(age)

# %%
age['kunal']

# %%
age['kunal'] = 44
print(age)

# %%
age['kunal':'mohit']

# %% [markdown]
# # Attributes in Pandas series

# %%
age

# %%
age.index

# %%
age.values

# %%
age.dtype

# %%
age.shape

# %%
age.size

# %%
age.ndim

# %%
age.name

# %% [markdown]
# # Aggregate functions in series

# %%
sales = pd.Series([560,340,210,980,564,340,340])
sales

# %%
sales.sum()

# %%
sales.min()

# %%
sales.max()

# %%
sales.mean()    # average

# %%
sales.median()

# %%
sales.mode()

# %%
sales.std()

# %%
sales.var()

# %%
sales.count()

# %% [markdown]
# # np.where

# %%
import numpy as np

print(sales)

np.where(sales>=500 , "good", "bad")

# %% [markdown]
# # apply method

# %%
print(sales)

def find_category(amount):
    if amount<400:
        return "Low"
    elif amount < 700:
        return "Mid"
    else:
        return "High"

sales.apply(find_category)

# %%
sales.apply(lambda amount : amount*0.05 if amount<=500 else amount*0.10)

# %% [markdown]
# # Data Frame

# %%
import os

os.listdir()

# %%
os.getcwd()

# %%
# if the file is in same folder 
df = pd.read_csv("store.csv")

# %%
# if file is not in the same folder 
df = pd.read_csv(r"C:\Users\deves\Documents\GitHub\Free_Datasets\Data Sets\store.csv")

# %%
df

# %% [markdown]
# # Know about your data

# %%
df.shape

# %%
df.info()

# %%
df.describe().round(2)

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit
# 0   11.45
# 1  762.18

# %%
df.tail(2)
# Out:
#            order_id           order_date           name           city  \
# 498  CA-2016-141586  2016-10-17 00:00:00   Neil Knudson  San Francisco
# 499  CA-2017-130386  2017-11-12 00:00:00  Nathan Gelder         Austin
#
#           state  post_code   region         category sub_category  sales  qty  \
# 498  California    94122.0     West  Office Supplies      Binders  18.16    5
# 499       Texas    78745.0  Central  Office Supplies        Paper  16.06    3
#
#      profit
# 498    6.58
# 499    5.82

# %%
df.sample(5)
# Out:
#            order_id           order_date                  name           city  \
# 253  CA-2017-144638  2017-03-10 00:00:00        Mick Hernandez        Chester
# 480  US-2016-108455  2016-12-02 00:00:00          Mike Kennedy  San Francisco
# 297  CA-2017-115427  2017-12-30 00:00:00            Erica Bern      Fairfield
# 307  CA-2016-141397  2016-06-20 00:00:00           Roy Collins       Pasadena
# 118  CA-2015-142755  2015-09-04 00:00:00  Christine Sundaresam        Roswell
#
#             state  post_code region         category sub_category   sales  \
# 253  Pennsylvania    19013.0   East  Office Supplies          Art    5.25
# 480    California    94122.0   West  Office Supplies        Paper   40.46
# 297    California    94533.0   West  Office Supplies      Binders   20.72
# 307    California    91104.0   West  Office Supplies      Binders   17.71
# 118       Georgia    30076.0  South       Technology  Accessories  619.95
#
#      qty  profit
# 253    2    0.59
# 480    7   19.83
# 297    2    6.48
# 307    3    6.42
# 118    5  111.59

# %%
# check null values
df.isnull().sum()
# Out:
# order_id         0
# order_date       0
# name             0
# city             0
# state            0
# post_code       16
# region           0
# category         0
# sub_category     0
# sales            0
# qty              0
# profit           0
# dtype: int64

# %%
# getting a list of all columns
df.columns
# Out:
# Index(['order_id', 'order_date', 'name', 'city', 'state', 'post_code',
#        'region', 'category', 'sub_category', 'sales', 'qty', 'profit'],
#       dtype='object')

# %% [markdown]
# # selecting single columns

# %%
# single column
df['name']
# Out:
# 0       Frank Merwin
# 1        Rick Hansen
# 2        Rick Hansen
# 3        Rick Hansen
# 4          Ryan Akin
#            ...
# 495       John Dryer
# 496       John Dryer
# 497       John Dryer
# 498     Neil Knudson
# 499    Nathan Gelder
# Name: name, Length: 500, dtype: object

# %%
df['sales']
# Out:
# 0        44.02
# 1      2309.65
# 2      1090.78
# 3        19.44
# 4       484.65
#         ...
# 495      10.19
# 496      16.78
# 497      13.12
# 498      18.16
# 499      16.06
# Name: sales, Length: 500, dtype: float64

# %%
# shortcut way to getting a column
df.sales
# Out:
# 0        44.02
# 1      2309.65
# 2      1090.78
# 3        19.44
# 4       484.65
#         ...
# 495      10.19
# 496      16.78
# 497      13.12
# 498      18.16
# 499      16.06
# Name: sales, Length: 500, dtype: float64

# %% [markdown]
# # Selecting multiple columns

# %%
col = ['name','sales','profit']
df[col]
# Out:
#               name    sales  profit
# 0     Frank Merwin    44.02   11.45
# 1      Rick Hansen  2309.65  762.18
# 2      Rick Hansen  1090.78 -290.88
# 3      Rick Hansen    19.44    9.33
# 4        Ryan Akin   484.65   92.08
# ..             ...      ...     ...
# 495     John Dryer    10.19    3.19
# 496     John Dryer    16.78   -0.21
# 497     John Dryer    13.12    3.77
# 498   Neil Knudson    18.16    6.58
# 499  Nathan Gelder    16.06    5.82
#
# [500 rows x 3 columns]

# %%
df[['name','sales','profit']]
# Out:
#               name    sales  profit
# 0     Frank Merwin    44.02   11.45
# 1      Rick Hansen  2309.65  762.18
# 2      Rick Hansen  1090.78 -290.88
# 3      Rick Hansen    19.44    9.33
# 4        Ryan Akin   484.65   92.08
# ..             ...      ...     ...
# 495     John Dryer    10.19    3.19
# 496     John Dryer    16.78   -0.21
# 497     John Dryer    13.12    3.77
# 498   Neil Knudson    18.16    6.58
# 499  Nathan Gelder    16.06    5.82
#
# [500 rows x 3 columns]

# %% [markdown]
# # Creating new columns

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit  new
# 0   11.45  100
# 1  762.18  100

# %%
df['new'] = 100

# %%
df['cost'] = df['sales'] - df['profit']

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit  new     cost
# 0   11.45  100    32.57
# 1  762.18  100  1547.47

# %%
# create a new column unit price (sales/qty)

# %%
# creating new column sales category using np.where If the sales amount is above 1000 it is high else low?  

df['sales_category'] = np.where(df['sales']>=1000 ,"High","Low")
df.head()
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 2  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 3  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 4  CA-2015-126445  2015-08-27 00:00:00     Ryan Akin       Murrieta
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
# 2    New York        NaN   East        Furniture       Tables  1090.78    7
# 3    New York        NaN   East  Office Supplies        Paper    19.44    3
# 4  California        NaN   West  Office Supplies      Storage   484.65    3
#
#    profit  new     cost sales_category
# 0   11.45  100    32.57            Low
# 1  762.18  100  1547.47           High
# 2 -290.88  100  1381.66           High
# 3    9.33  100    10.11            Low
# 4   92.08  100   392.57            Low
