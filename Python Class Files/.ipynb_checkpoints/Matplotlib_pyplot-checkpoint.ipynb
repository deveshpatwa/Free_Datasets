# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data file

df = pd.read_csv(r"C:\Users\deves\Documents\GitHub\Free_Datasets\Data Sets\store.csv")

# %%
df.head()
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 2  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 3  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 4  CA-2015-126445  2015-08-27 00:00:00     Ryan Akin       Murrieta
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
# 2    New York        NaN   East        Furniture       Tables  1090.78    7
# 3    New York        NaN   East  Office Supplies        Paper    19.44    3
# 4  California        NaN   West  Office Supplies      Storage   484.65    3
#
#    profit
# 0   11.45
# 1  762.18
# 2 -290.88
# 3    9.33
# 4   92.08

# %%
# bar chart

df.groupby("region")['sales'].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='region'>

# %%
# barh chart

df.groupby("region")['sales'].sum().plot(kind="barh")
# Out:
# <Axes: ylabel='region'>

# %%
# barh chart formating

plt.figure(figsize=(9,6))

df.groupby("sub_category")['sales'].sum().sort_values().plot(kind="barh",color="gray")

plt.title("Sub category wise total sales",size=15,color="blue",fontweight="bold")
plt.xlabel("Sales")
plt.ylabel("Sub category")
plt.show()

# %%
# Pie chart
df.category.value_counts().plot(kind="pie")

plt.show()

# %%
# Line chart
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      500 non-null    object
#  1   order_date    500 non-null    object
#  2   name          500 non-null    object
#  3   city          500 non-null    object
#  4   state         500 non-null    object
#  5   post_code     484 non-null    float64
#  6   region        500 non-null    object
#  7   category      500 non-null    object
#  8   sub_category  500 non-null    object
#  9   sales         500 non-null    float64
#  10  qty           500 non-null    int64
#  11  profit        500 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 47.0+ KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month

# %%
df.head()
# Out:
#          order_id order_date          name           city       state  \
# 0  CA-2016-155488 2016-11-13  Frank Merwin      Vancouver  Washington
# 1  CA-2015-124891 2015-07-31   Rick Hansen  New York City    New York
# 2  CA-2015-124891 2015-07-31   Rick Hansen  New York City    New York
# 3  CA-2015-124891 2015-07-31   Rick Hansen  New York City    New York
# 4  CA-2015-126445 2015-08-27     Ryan Akin       Murrieta  California
#
#    post_code region         category sub_category    sales  qty  profit  year  \
# 0    98661.0   West  Office Supplies          Art    44.02    2   11.45  2016
# 1        NaN   East       Technology  Accessories  2309.65    7  762.18  2015
# 2        NaN   East        Furniture       Tables  1090.78    7 -290.88  2015
# 3        NaN   East  Office Supplies        Paper    19.44    3    9.33  2015
# 4        NaN   West  Office Supplies      Storage   484.65    3   92.08  2015
#
#    month
# 0     11
# 1      7
# 2      7
# 3      7
# 4      8

# %%
plt.figure(figsize=(12,4))

df.groupby(['year','month'])['sales'].sum().plot(kind='line')
plt.show()

# %%
plt.figure(figsize=(12,4))

df.groupby(['year','month'])['sales'].sum().plot(kind='area')
plt.show()

# %%
profit =  df[['order_date','profit']].sort_values(by='order_date').reset_index()['profit']

# %%
profit.cumsum().plot()
plt.show()

# %% [markdown]
# # Hist plot

# %%
df.qty.plot(kind='hist')
plt.show()

# %%
df.qty.plot(kind='box')
plt.show()

# %% [markdown]
# # Scatter plot chart

# %%
car = pd.read_csv(r"C:\Users\deves\Documents\GitHub\Free_Datasets\Data Sets\car_average.csv")
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320

# %%
car['origin'] =  car['origin'].astype(str)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
car.plot(kind='scatter',x='horsepower',y='mpg',color='green')
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
# set theme
sns.set_theme(style='darkgrid')

# %% [markdown]
# ## Hist plot

# %%
sns.histplot(data=car,x='horsepower',color="black",kde=True)

plt.title("Histogram",size=15,fontweight="bold")
plt.show()

# %% [markdown]
# # scatter plot

# %%
sns.scatterplot(data=car,x='horsepower',y='mpg',hue="cylinders")
plt.show()

# %% [markdown]
# # Regplot

# %%
sns.regplot(data=car,x="horsepower",y="mpg")
plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(data=car,x="horsepower",y='origin')
plt.show()
