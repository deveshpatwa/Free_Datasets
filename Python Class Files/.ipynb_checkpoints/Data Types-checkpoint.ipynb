# %% [markdown]
# # Data Types in Python
# - int
# - float
# - str
# - bool
# - complex
# - list
# - tuple
# - set
# - dict

# %% [markdown]
# # int

# %%
a = 90

type(a)
# Out:
# int

# %%
b = "89"
b = int(b)
type(b)
# Out:
# int

# %% [markdown]
# # Float

# %%
a = 8.7563
type(a)
# Out:
# float

# %% [markdown]
# # Complex

# %%
a = 4j
type(a)
# Out:
# complex

# %% [markdown]
# # Str
# - A string in Python is a sequence of characters enclosed in quotes.
# - You can use single (' '), double (" "), or triple quotes (''' ''' or """ """) for multi-line strings.
# - Strings are immutable, meaning once created, their content cannot be changed.
# - Each character in a string has order an index, starting from 0.
# - You can access, slice, and loop through strings easily.

# %%
text = 'hello'

# %%
text = 'hello
how are 
you'
# Out:
#   Cell In[11], line 1
#     text = 'hello
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
text = '''hello
how are 
you'''

# %%
text
# Out:
# 'hello\nhow are \nyou'

# %%
print(text)
# Out:
# hello
# how are
# you

# %% [markdown]
# # Indexing

# %%
a = "python is good"
print(a[0])
print(a[3])
print(a[-1])
# Out:
# p
# h
# d

# %% [markdown]
# # Slicing

# %%
a = "python is good"

# find 'thon'
a[2:6]
# Out:
# 'thon'

# %%
a = "python is good"

# find 'python'
# find 'good'
# find 'on is'
# Out:
# 'good'

# %%
a = "python is good"

# find 'yhn'
a[1:6:2]

# find 'ph  o'
# Out:
# 'yhn'

# %%
a = "python is good"
a[5:1:-1]
# Out:
# 'noht'

# %%
name = "rohan"
name[ : :-1]
# Out:
# 'nahor'

# %%
# Write a program to check if a name is a palindrome or not

# %% [markdown]
# A **mutable object** is one whose data can be modiﬁed in place without creating a new object.
# This means the object’s identity (memory address) stays the same, but its contents can
# change. Common mutable objects in Python include lists, dictionaries, sets, and bytearrays.
# For example, if you have a list and you change one of its elements, the same list object is
# updated rather than creating a new list.
#
# An **immutable object** is one whose value cannot be changed after it is created. If you try to
# modify an immutable object, Python creates a new object instead of changing the existing
# one. Common immutable objects include integers, ﬂoats, strings, tuples, and frozensets. For
# example, when you change a string, Python actually creates a new string rather than
# modifying the original one.

# %%
a = 'python'
a[0] = 'k'
print(a)

# %%
b = [4,7,2]
b[0]  = 15
print(b)

# %%
a = 10
print(id(a))
print(a)

a = a+15
print(id(a))
print(a)

# %% [markdown]
# # Methods in string

# %%
a = "pytHON IS gOOd"
a.upper()

# %%
a = "pytHON IS gOOd"
a.lower()

# %%
a = "pytHON IS gOOd"
a.capitalize()

# %%
a = "pytHON IS gOOd"
a.title()

# %%
# Find how many 'a' are in this text using for loop ?

text = "A good day to drive A car"
count = 0

for i in text.lower():
    if i == "a":
        count += 1

print(count)

# %%
a = "       pytHON IS gOOd        "
a

# %%
a = "       pytHON   IS gOOd        "
a.strip()

# %%
a = 'python'
a.replace("t","z")

# %%
text = "A good day to drive A car"
text.replace("car","bike")

# %%
# replace all the "A" to "Q"
text = "A good day to drive A car"
text.lower().replace("a","Q")

# %%
# You have to add these two amounts
a = "$230"
b = "$480"

print(a+b)  #Output - 710

# %%
text = "A good day to drive A car"
text.split()

# %%
name = 'rohan_kumar'
name.split("_")

# %%
data = ['A', 'good', 'day', 'to', 'drive', 'A', 'car']
"_".join(data)

# %%
a = "python is good"
a.find("z")

# %%
a = "python is good and it is also easy "
a.count("is")

# %%
a = "90"
a.isdigit()

# %%
a = "hello world"
a.isalpha()

# %%
a = "hello45"
a.isalnum()

# %%
# You have to add (3453+758) = 4211

a = "3hj4h5g3fep"
b ="kg75yfde8"

clean_a = ""
clean_b = ""

for i in a:
    if i.isdigit():
        clean_a += i

for i in b:
    if i.isdigit():
        clean_b += i


print(int(clean_a)+int(clean_b))

# %%
# Separate digit,text and special from a = “3248wdhfh8347h7sfd*T&^g&^R&^76@#%$”
# Write a program to check whether a character is a letter, and if it is, check whether it’s
# uppercase or lowercase

# Count how many vowels are in this text a = “this is a random text”

# %% [markdown]
# # List
#
# a list is a collection data type that can store multiple items in a single variable. It is one of
# the most commonly used and ﬂexible data structures in Python. A list is written using
# square brackets [ ], and the items inside it are separated by commas.
#
# - Ordered – The items have a deﬁned order and can be accessed using an index.
# - Mutable – You can change, add, or remove items after creating the list.
# - Allows duplicates – Lists can contain duplicate values.
# - Can store mixed data types – A list can have strings, integers, ﬂoats, and even other lists.

# %%
data = [5,9,3,6,2]
print(data)

# %%
data[1]

# %%
data[-1]

# %%
data[1:4]

# %%
a = [3,6,4,3,3,4]
a

# %%
data = ["rohan",56,78.34,[34,87,23]]
data

# %%
names = ["rohan","mohit","kunal"]
names.append("suman")
print(names)

# %%
names = ["rohan","mohit","kunal"]
names.insert(1,"suman")
print(names)

# %%
names = ["rohan","mohit","kunal"]
names.append("suman","naman")
print(names)

# %%
names = ["rohan","mohit","kunal"]
names.extend(["naman","sunita"])
print(names)
# Out:
# ['rohan', 'mohit', 'kunal', 'naman', 'sunita']

# %%
names = ["rohan","mohit","kunal"]
names.append(["naman","sunita"])
print(names)
# Out:
# ['rohan', 'mohit', 'kunal', ['naman', 'sunita']]

# %%
names = ["rohan","mohit","kunal"]
names.remove("mohit")
print(names)
# Out:
# ['rohan', 'kunal']

# %%
names = ["rohan","mohit","kunal","mohit"]
names.remove("mohit")
print(names)
# Out:
# ['rohan', 'kunal', 'mohit']

# %%
names = ["rohan","mohit","kunal"]
names.pop(0)
print(names)
# Out:
# ['mohit', 'kunal']

# %%
names = ["rohan","mohit","kunal"]
names.pop(1)
# Out:
# 'mohit'

# %%
names = ["rohan","mohit","kunal"]
names.pop()
# Out:
# 'kunal'

# %%
names = ["rohan","mohit","kunal"]
names.clear()
names
# Out:
# []

# %%
names = ["rohan","mohit","kunal","suman"]
names.index("kunal")
# Out:
# 2
