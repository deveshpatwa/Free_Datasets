# %% [markdown]
# # Comparison (Relational) Operators

# %%
34 > 8

# %%
4 = 4

# %%
5 == 5

# %%
"rohan" == "Rohan"

# %%
45 != 89

# %%
45 <5

# %% [markdown]
# # If Function

# %%
# Find if the person can vote or not
age = int(input("Enter your age"))

if age>=18 :
    print("can vote")
else:
    print("can not vote")

# %% [markdown]
# **Indentation** :
#
# - indentation means adding spaces or tabs at the beginning of a line to deﬁne blocks of code.
# - Unlike many other programming languages (like C or Java) that use { } to mark code blocks
# - Python uses indentation to show which statements belong together.

# %%
# Write a program to check whether a number is positive or negative.
num = int(input("Enter a number"))

if num>0:
    print("Positive")
else:
    print("Negative")

# %%
# Write a program to check if a number is even or odd.
num = int(input("Enter a number"))

if num%2 == 0 :
    print("Even")
else:
    print("odd")

# %%
# Write a program to print “Welcome” if the user enters the correct password.
password = "1234"
user = input()

if password == user:
    print("Welcome")
else:
    print("Wrong password")

# %%
# Write a program to check if a given number is divisible by 5.

# %%
# Write a program to check if a number is greater than 100 or not.

# %%
# Write a program to check whether a year is a leap year or not.
year = 2100

if year%400 == 0 or (year%4 == 0 and year%100 != 0):
    print("Leap year")
else:
    print("Normal year")

# %%
# Write a program to ﬁnd the largest of two numbers.

# %%
# Write a program to check whether a character is a vowel or consonant.

# %%
# Write a program to check whether a person can drive (age ≥ 18).

# %%
# Write a program to check whether a number is divisible by both 3 and 5.

# %% [markdown]
# # If with two condition

# %% [markdown]
# # Logical Operators
# When you have to ckeck more then one condition

# %%
45 >4  and  20==5

# %%
45 >4  or  20==5

# %%
not 34>100

# %%
# You can get a bike only if you score above 80 Marks and our budget is above 5,00,000?
marks = 98
budget = 600000

if marks >=80 and budget >= 500000:
    print("You can get a bike")
else:
    print("You will not get a bike")

# %%
# Create a full login window where if the username and password are correct then only 
# you can welcome else incorrect

# %% [markdown]
# # Nested If

# %%
age = int(input("Whate is your age"))

if age >= 18:
    print("Adult")
    budget = int(input("What is you budget ?"))
    if budget >= 500000:
        print("you can get a car")
    else:
        print("you can get a Bike")

else:
    print("Child")
    marks = int(input("what are you school marks"))
    if marks> 70:
        print("you get a Cycle")
    else:
        print("You get a Board game Ludo")
# Out:
# Child
# You get a Board game Ludo

# %% [markdown]
# # if .. elif .. elif .. else

# %%
# Grade the student on the basis of Marks
marks = 95

if marks >= 90:
    print("A")
elif marks >= 70:
    print("B")
elif marks >= 50:
    print("C")
elif marks > 33:
    print("D")
else:
    print("F")
# Out:
# A

# %%
# find the sales category using sales value
# 0 - 500 - low
# 500 - 2k - mid
# 2k - 5k - high
# above 5k - very high


sales = 4500

# %%
# Find the discount amount on the basis of sales
# below 1200 - 5%
# 1200 - 4000 - 8%
# above 4000 - 12%

sales = 4780

# expected output - 12 % discount on 4780 is 573.6
# Out:
# 12.0% discount on 4780 is 573.6

# %% [markdown]
# # ternary operator (Shortcut of if function)

# %%
age = 45

"can vote" if age >= 18 else "can not vote"
# Out:
# 'can vote'

# %%
# Give discount 12% only if the sales is above 5000 else 0

sales = 2500
discount = sales*12/100 if sales >= 5000 else 0

print(discount)
# Out:
# 0

# %%
# Find the discount rate on the basis of sales
# below 1200 - 5%
# 1200 - 4000 - 8%
# above 4000 - 12%

sales = 34

print('5%') if sales < 1200 else print("8%") if sales < 4000 else print("12%")
# Out:
# 5%
