# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\deves\Documents\GitHub\Free_Datasets\Python Class Files\store.csv")

# %%
df.groupby("region")['sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>
