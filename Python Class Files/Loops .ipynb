# %% [markdown]
# # For Loop

# %%
print("Hello")
print("Hello")
print("Hello")
# Out:
# Hello
# Hello
# Hello

# %%
# Working with number of repeatation
for i in range(10):
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
# Working with alphabets

for i in "Hello world":
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
# When working with list

names = ['']
