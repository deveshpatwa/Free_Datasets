# %% [markdown]
# ## FMCG Data Analysis

# %% [markdown]
# ### Total Sales and Quantity
# Calculate the total Sales and total Qty across the entire dataset.

# %% [markdown]
# ### Monthly Sales Summary
#
# Group the data by Month and show total Sales and Qty for each month.

# %% [markdown]
# ### Top Selling Products
#
# Find the top 5 products based on total Sales and total Qty.

# %% [markdown]
# ### Channel-wise Performance
#
# Group the data by Channel and calculate total Sales and average Qty.

# %% [markdown]
# ### Sub-Channel Analysis
#
# Show total Sales and number of products sold under each Sub-Channel.

# %% [markdown]
# ### Average Quantity Sold per Product
#
# For each product, calculate the average quantity sold across all months.

# %% [markdown]
# ### Price Per Unit Estimation
#
# Create a new column for Price per Unit = Sales ÷ Qty

# %% [markdown]
# ### Category-wise Sales Summary
#
# Calculate the total and average Sales for each Category.

# %% [markdown]
# ### Most Consistent Product
#
# Identify the product with the least variation in monthly sales using standard deviation.
