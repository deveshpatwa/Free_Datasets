# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head(2)

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe().round(1)

# %%
df['Age']

# %%
df.columns

# %%
df['Age'].describe()

# %%
df[['Name','Age']]

# %%
df['hello'] = 100

# %%
df.head(2)

# %%
df['new age'] = df['Age'] / 2

# %%
df.head()

# %%
df['hello'] = 150

# %%
df.head()

# %%
df['age_category'] = np.where(df['Age']>=30,"old","Young")

# %%
def find_age_cat(age):
    if age<=12:
        return "Child"
    elif age <= 19:
        return "Teen"
    elif age<= 50:
        return "Adult"
    else:
        return "Old"

# %%
df['Age'].apply(find_age_cat)

# %%
def last(name):
    return name.split(",")[1]

df['Name'].apply(last)

# %%
df['Name'].apply(lambda name : name.split(",")[1])

# %%
# find only first name 
df['check'] =  df['Name'].apply(lambda x : x.split(".")[1].split("(")[0].split('"')[0].strip())

# %%
df['check'].sample(20)
# Out:
# 245        William Edward
# 462              Arthur H
# 289                  Kate
# 890               Patrick
# 725                  Luka
# 483
# 856        George Dennick
# 585                  Ruth
# 184        Luise Gretchen
# 773                  Dibo
# 511                 James
# 750                  Joan
# 847                 Marin
# 303                Nora A
# 244               Sleiman
# 377          Harry Elkins
# 302    William Cahoone Jr
# 147         Robina Maggie
# 820      Charles Melville
# 118          Quigg Edmond
# Name: check, dtype: object

# %%
df['check']
# Out:
# 0          Owen Harris
# 1         John Bradley
# 2                Laina
# 3        Jacques Heath
# 4        William Henry
#             ...
# 886             Juozas
# 887     Margaret Edith
# 888    Catherine Helen
# 889        Karl Howell
# 890            Patrick
# Name: check, Length: 891, dtype: object

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  hello  new age age_category  \
# 0      0  A/5 21171   7.2500   NaN        S    150     11.0        Young
# 1      0   PC 17599  71.2833   C85        C    150     19.0          old
#
#           check
# 0   Owen Harris
# 1  John Bradley
