# %%
# Q1: Load the provided dataset into a pandas DataFrame and display the first 5 rows.

# %%
# Q2: Display the basic summary information (column data types, non-null counts) of the dataset using info().

# %%
# Q3: Find the total number of rows and columns present in the dataset.

# %%
# Q4: List all the unique car companies present in the dataset.

# %%
# Q5: Calculate the average price of all cars in the dataset.

# %%
# Q6: Filter and display all rows where the car's body_style is 'convertible'.

# %%
# Q7: Find the maximum and minimum horsepower among all cars.

# %%
# Q8: Group the dataset by 'company' and calculate the average price for each company.

# %%
# Q9: Count the occurrences of each engine_type using value_counts().

# %%
# Q10: Create a new column named 'price_per_hp' by dividing 'price' by 'horsepower'.

# %%
# Q11: Find the car(s) with the highest mileage in the dataset.

# %%
# Q12: Sort the entire DataFrame by 'price' in descending order.

# %%
# Q13: Filter for cars that have a 'mileage' greater than 20 and a 'price' less than 15,000.

# %%
# Q14: Plot a bar chart showing the average horsepower for each body_style.

# %%
# Q15: Map the word values in 'num_of_cylinders' (e.g., 'four', 'six') to numeric values (e.g., 4, 6) using a custom function or mapping dictionary.

# %%
# Q16: Compute the correlation matrix for all numerical features and visualize it using a heatmap.

# %%
# Q17: Perform a multi-level group-by operation to find the max 'price' and mean 'mileage' for each combination of 'company' and 'body_style'.

# %%
# Q18: Identify and extract outliers in the 'price' column using the IQR (Interquartile Range) method.
