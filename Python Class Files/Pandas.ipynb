# %% [markdown]
# # Pandas Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
s = pd.Series([230,450,980,500,1200])
print(s)

# %%
# Try  +   -    *    /  //   **  %

s * 2

# %% [markdown]
# # Indexing and slicing

# %%
print(s)

# %%
s[2] = 552

# %%
# Negative indexing does not work in the series 
s[-1]

# %%
print(s)

# %%
s[1:4]

# %% [markdown]
# # Name index

# %%
age = pd.Series({"rohan":34,"kunal":78,"kartik":23,"mohit":12,"naman":46})
print(age)

# %%
age['kunal']

# %%
age['kunal'] = 44
print(age)

# %%
age['kunal':'mohit']

# %% [markdown]
# # Attributes in Pandas series

# %%
age

# %%
age.index

# %%
age.values

# %%
age.dtype

# %%
age.shape

# %%
age.size

# %%
age.ndim

# %%
age.name

# %% [markdown]
# # Aggregate functions in series

# %%
sales = pd.Series([560,340,210,980,564,340,340])
sales

# %%
sales.sum()

# %%
sales.min()

# %%
sales.max()

# %%
sales.mean()    # average

# %%
sales.median()

# %%
sales.mode()

# %%
sales.std()

# %%
sales.var()

# %%
sales.count()

# %% [markdown]
# # np.where

# %%
import numpy as np

print(sales)

np.where(sales>=500 , "good", "bad")

# %% [markdown]
# # apply method

# %%
print(sales)

def find_category(amount):
    if amount<400:
        return "Low"
    elif amount < 700:
        return "Mid"
    else:
        return "High"

sales.apply(find_category)

# %%
sales.apply(lambda amount : amount*0.05 if amount<=500 else amount*0.10)

# %% [markdown]
# # Data Frame

# %%
import os

os.listdir()

# %%
os.getcwd()

# %%
# if the file is in same folder 
df = pd.read_csv("store.csv")

# %%
# if file is not in the same folder 
df = pd.read_csv(r"C:\Users\deves\Documents\GitHub\Free_Datasets\Data Sets\store.csv")

# %%
df

# %% [markdown]
# # Know about your data

# %%
df.shape

# %%
df.info()

# %%
df.describe().round(2)

# %%
df.head(2)

# %%
df.tail(2)

# %%
df.sample(5)

# %%
# check null values
df.isnull().sum()

# %%
# getting a list of all columns
df.columns

# %% [markdown]
# # selecting single columns

# %%
# single column
df['name']

# %%
df['sales']

# %%
# shortcut way to getting a column
df.sales

# %% [markdown]
# # Selecting multiple columns

# %%
col = ['name','sales','profit']
df[col]

# %%
df[['name','sales','profit']]

# %% [markdown]
# # Creating new columns

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit
# 0   11.45
# 1  762.18

# %%
df['new'] = 100

# %%
df['cost'] = df['sales'] - df['profit']

# %%
df.head(2)

# %%
# create a new column unit price (sales/qty)

# %%
# creating new column sales category using np.where If the sales amount is above 1000 it is high else low?  

df['sales_category'] = np.where(df['sales']>=1000 ,"High","Low")
df.head()

# %%
# Create a new column for sales category low Medium and High?
def sales_cat(amount):
    if amount <= 100:
        return "Low"
    elif amount <= 1000:
        return "Mid"
    else:
        return "High"

df['sales_category'] = df['sales'].apply(sales_cat)

# %%
df.head()
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 2  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 3  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
# 4  CA-2015-126445  2015-08-27 00:00:00     Ryan Akin       Murrieta
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
# 2    New York        NaN   East        Furniture       Tables  1090.78    7
# 3    New York        NaN   East  Office Supplies        Paper    19.44    3
# 4  California        NaN   West  Office Supplies      Storage   484.65    3
#
#    profit sales_category
# 0   11.45            Low
# 1  762.18           High
# 2 -290.88           High
# 3    9.33            Low
# 4   92.08            Mid

# %% [markdown]
# # delete columns and rows

# %%
df.drop(columns="city")   # temp
df = df.drop(columns="sales_category")   # permanent delete

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit
# 0   11.45
# 1  762.18

# %%
df.drop(index=2)
# Out:
#            order_id           order_date           name           city  \
# 0    CA-2016-155488  2016-11-13 00:00:00   Frank Merwin      Vancouver
# 1    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 3    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 4    CA-2015-126445  2015-08-27 00:00:00      Ryan Akin       Murrieta
# 5    CA-2015-111199  2015-11-13 00:00:00  Joe Kamberova   Jacksonville
# ..              ...                  ...            ...            ...
# 495  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 496  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 497  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 498  CA-2016-141586  2016-10-17 00:00:00   Neil Knudson  San Francisco
# 499  CA-2017-130386  2017-11-12 00:00:00  Nathan Gelder         Austin
#
#               state  post_code   region         category sub_category  \
# 0        Washington    98661.0     West  Office Supplies          Art
# 1          New York        NaN     East       Technology  Accessories
# 3          New York        NaN     East  Office Supplies        Paper
# 4        California        NaN     West  Office Supplies      Storage
# 5    North Carolina        NaN    South  Office Supplies        Paper
# ..              ...        ...      ...              ...          ...
# 495           Texas    75019.0  Central  Office Supplies          Art
# 496           Texas    75019.0  Central  Office Supplies      Storage
# 497           Texas    75019.0  Central  Office Supplies          Art
# 498      California    94122.0     West  Office Supplies      Binders
# 499           Texas    78745.0  Central  Office Supplies        Paper
#
#        sales  qty  profit
# 0      44.02    2   11.45
# 1    2309.65    7  762.18
# 3      19.44    3    9.33
# 4     484.65    3   92.08
# 5     115.30    3   40.35
# ..       ...  ...     ...
# 495    10.19    7    3.19
# 496    16.78    1   -0.21
# 497    13.12    5    3.77
# 498    18.16    5    6.58
# 499    16.06    3    5.82
#
# [499 rows x 12 columns]

# %%
df.drop(index=[0,2,3])
# Out:
#            order_id           order_date           name           city  \
# 1    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 4    CA-2015-126445  2015-08-27 00:00:00      Ryan Akin       Murrieta
# 5    CA-2015-111199  2015-11-13 00:00:00  Joe Kamberova   Jacksonville
# 6    CA-2015-105312  2015-11-06 00:00:00    Meg Tillman     Scottsdale
# 7    CA-2015-105312  2015-11-06 00:00:00    Meg Tillman     Scottsdale
# ..              ...                  ...            ...            ...
# 495  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 496  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 497  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 498  CA-2016-141586  2016-10-17 00:00:00   Neil Knudson  San Francisco
# 499  CA-2017-130386  2017-11-12 00:00:00  Nathan Gelder         Austin
#
#               state  post_code   region         category sub_category  \
# 1          New York        NaN     East       Technology  Accessories
# 4        California        NaN     West  Office Supplies      Storage
# 5    North Carolina        NaN    South  Office Supplies        Paper
# 6           Arizona        NaN     West  Office Supplies    Envelopes
# 7           Arizona        NaN     West  Office Supplies      Binders
# ..              ...        ...      ...              ...          ...
# 495           Texas    75019.0  Central  Office Supplies          Art
# 496           Texas    75019.0  Central  Office Supplies      Storage
# 497           Texas    75019.0  Central  Office Supplies          Art
# 498      California    94122.0     West  Office Supplies      Binders
# 499           Texas    78745.0  Central  Office Supplies        Paper
#
#        sales  qty  profit
# 1    2309.65    7  762.18
# 4     484.65    3   92.08
# 5     115.30    3   40.35
# 6       7.08    3    2.48
# 7       4.40    3   -3.52
# ..       ...  ...     ...
# 495    10.19    7    3.19
# 496    16.78    1   -0.21
# 497    13.12    5    3.77
# 498    18.16    5    6.58
# 499    16.06    3    5.82
#
# [497 rows x 12 columns]

# %% [markdown]
# # Rename a column

# %%
df.head(2)
# Out:
#          order_id           order_date          name           city  \
# 0  CA-2016-155488  2016-11-13 00:00:00  Frank Merwin      Vancouver
# 1  CA-2015-124891  2015-07-31 00:00:00   Rick Hansen  New York City
#
#         state  post_code region         category sub_category    sales  qty  \
# 0  Washington    98661.0   West  Office Supplies          Art    44.02    2
# 1    New York        NaN   East       Technology  Accessories  2309.65    7
#
#    profit
# 0   11.45
# 1  762.18

# %%
df.rename(columns={"city":"location"})
# Out:
#            order_id           order_date           name       location  \
# 0    CA-2016-155488  2016-11-13 00:00:00   Frank Merwin      Vancouver
# 1    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 2    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 3    CA-2015-124891  2015-07-31 00:00:00    Rick Hansen  New York City
# 4    CA-2015-126445  2015-08-27 00:00:00      Ryan Akin       Murrieta
# ..              ...                  ...            ...            ...
# 495  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 496  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 497  CA-2017-152485  2017-09-04 00:00:00     John Dryer        Coppell
# 498  CA-2016-141586  2016-10-17 00:00:00   Neil Knudson  San Francisco
# 499  CA-2017-130386  2017-11-12 00:00:00  Nathan Gelder         Austin
#
#           state  post_code   region         category sub_category    sales  \
# 0    Washington    98661.0     West  Office Supplies          Art    44.02
# 1      New York        NaN     East       Technology  Accessories  2309.65
# 2      New York        NaN     East        Furniture       Tables  1090.78
# 3      New York        NaN     East  Office Supplies        Paper    19.44
# 4    California        NaN     West  Office Supplies      Storage   484.65
# ..          ...        ...      ...              ...          ...      ...
# 495       Texas    75019.0  Central  Office Supplies          Art    10.19
# 496       Texas    75019.0  Central  Office Supplies      Storage    16.78
# 497       Texas    75019.0  Central  Office Supplies          Art    13.12
# 498  California    94122.0     West  Office Supplies      Binders    18.16
# 499       Texas    78745.0  Central  Office Supplies        Paper    16.06
#
#      qty  profit
# 0      2   11.45
# 1      7  762.18
# 2      7 -290.88
# 3      3    9.33
# 4      3   92.08
# ..   ...     ...
# 495    7    3.19
# 496    1   -0.21
# 497    5    3.77
# 498    5    6.58
# 499    3    5.82
#
# [500 rows x 12 columns]

# %%
# df.columns

# %%
# for i in df.columns:
#     print(i,i.upper())

# %%
# df.rename(columns={ i : i.upper() for i in df.columns})
