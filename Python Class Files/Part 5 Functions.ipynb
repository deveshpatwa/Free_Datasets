# %% [markdown]
# # Function
#
# a function is a block of code that performs a specific task and can be reused whenever
# needed. It helps make programs shorter, cleaner, and easier to manage. A function is defined
# using the def keyword followed by the function name, parentheses (which may include
# parameters), and a colon. The code inside the function is indented.
# Types of functions
# - Built-in Functions
# - User-defined Functions

# %% [markdown]
# # Built-in Functions

# %%
sum([4,6,2,1])
# Out:
# 13

# %%
min([3,7,89,3,1])
# Out:
# 1

# %%
max([3,7,89,3,1])
# Out:
# 89

# %%
len([3,7,89,3,1])
# Out:
# 5

# %%
len("hello world")
# Out:
# 11

# %%
# sorted
a = [5,9,2,6,3,8]
print(sorted(a))
print(a)
# Out:
# [2, 3, 5, 6, 8, 9]
# [5, 9, 2, 6, 3, 8]

# %%
# sort method
a = [5,9,2,6,3,8]
a.sort()
print(a)
# Out:
# [2, 3, 5, 6, 8, 9]

# %%
a = (5,9,2,6,3,8)
sorted(a)
# Out:
# [2, 3, 5, 6, 8, 9]

# %%
a = {5,9,2,6,3,8}
sorted(a)
# Out:
# [2, 3, 5, 6, 8, 9]

# %%
a = [5,9,2,6,3,8]
sorted(a,reverse=True)
# Out:
# [9, 8, 6, 5, 3, 2]

# %%
# Zip
sub = ['maths','english','hindi','science']
marks = [78,99,56,67]
list(zip(sub,marks))
# Out:
# [('maths', 78), ('english', 99), ('hindi', 56), ('science', 67)]

# %%
# Zip
sub = ['maths','english','hindi','science']
marks = [78,99,56,67]
dict(zip(sub,marks))
# Out:
# {'maths': 78, 'english': 99, 'hindi': 56, 'science': 67}

# %%
# Map   -> map(function,list)
data = [4,8,9,12,4,6]

list(map(lambda x: x**2,data))
# Out:
# [16, 64, 81, 144, 16, 36]

# %%
list(map(even_odd,data))
# Out:
# ['Even', 'Even', 'Odd', 'Even', 'Even', 'Even']

# %%
data = [450,900,1240,670,345]
discount = list(map(lambda x : x*15/100,data))

print(discount)
# Out:
# [67.5, 135.0, 186.0, 100.5, 51.75]

# %% [markdown]
# # User Defined Functions
#
# - User-defined functions in Python are the functions that you create yourself to perform specific tasks.
# - They help make your code more organized, reusable, and easier to understand.
# - You define a function using the def keyword, give it a name, optionally add parameters, and then write the code that runs when the function is called.

# %%
# discount(amount,rate)
def discount(amount,rate):
    disc = amount * rate / 100
    return disc

discount(5000,4.8)
# Out:
# 240.0

# %%
discount(49800,12.8)
# Out:
# 6374.4

# %%
# even_odd(num)
def even_odd(num):
    if num%2==0:
        return "Even"
    else:
        return "Odd"

even_odd(89)
# Out:
# 'Odd'

# %%
# sqr(num)    - return the sqr of that number

# %%
# table(num)   - print the table of that number

# %%
# greet_user()  - take name as input and greet them

def greet_user():
    print(f"hello, User")

greet_user()

# %%
# add(num1,num2)
def add(num1,num2):
    return num1+num2

add(56,90) +200
# Out:
# 346

# %%
# add(num1,num2)
def add(num1,num2):
    print(num1+num2)

add(56,90) + 200
# Out:
# 146
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 def add(num1,num2):
#       3     print(num1+num2)
# ----> 5 add(56,90) + 200
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
None + 56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 None + 56
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# # Types of variables in a function
# **global and a local variable**
# - a local variable is a variable that is created inside a function and can be used only within that function. It exists only while the function is running, and once the function finishes execution, the local variable is destroyed. This means you cannot access a local variable outside the function in which it is defined.
# - A global variable, on the other hand, is a variable that is defined outside of all functions, usually at the top level of a program. A global variable can be accessed from anywhere in the code, including inside functions.

# %%
a = 45

def test():
    b = 20
    print(a)
    print(b)

test()
# Out:
# 45
# 20

# %%
print(a)
print(b)
# Out:
# 45
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 print(a)
# ----> 2 print(b)
#
# NameError: name 'b' is not defined

# %%
a = 111

def test():
    global b
    b = 445
    print(a)
    print(b)

test()
# Out:
# 111
# 445

# %%
print(a)
print(b)
# Out:
# 111
# 445

# %% [markdown]
# # Doc String
# A docstring (documentation string) in Python is a string literal used to explain the purpose
# and behavior of modules, classes, functions, or methods. Defined using triple quotes (""")
# immediately following the object's definition, it becomes part of the code's metadata,
# making it accessible at runtime via __doc__ or help().

# %%
# discount(amount,rate)
def discount(amount,rate):
    """ This function will calculate the discount by using amount and rate given by the user"""
    disc = amount * rate / 100
    return disc

discount(5000,8.7)
# Out:
# 435.0

# %%
help(discount)
# Out:
# Help on function discount in module __main__:
#
# discount(amount, rate)
#     This function will calculate the discount by using amount and rate given by the user

# %%
discount.__doc__
# Out:
# ' This function will calculate the discount by using amount and rate given by the user'

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# # Types of parameters

# %%
# Positional Parameters 

def greet(name,age):
    print(f"your name is {name} and your age is {age}")

greet("rohan",34)
greet(34,"rohan")
# Out:
# your name is rohan and your age is 34
# your name is 34 and your age is rohan

# %%
# Keyword Parameters

def greet(name,age):
    print(f"your name is {name} and your age is {age}")

greet(age=34,name="rohan")
# Out:
# your name is rohan and your age is 34

# %%
# Default Parameters

def discount(amount,rate=12):
    disc = amount * rate / 100
    return disc

discount(5000,17.45)
# Out:
# 872.5

# %%
# Arbitrary parameters: Use an asterisk * before a parameter name to accept any number of positional arguments. The function receives them as a tuple.

a = 4,5,2,8,5
print(a)
# Out:
# (4, 5, 2, 8, 5)

# %%
def total(*a):
    total_of_numbers = 0
    for i in a:
        total_of_numbers += i
    return total_of_numbers

total(4,5,6,90)
# Out:
# 105

# %%
# Arbitrary Keyword Parameters (**kwargs)
def people(**info):
    print(info)
    print(type(info))

people(name='rohan',age=45)
# Out:
# {'name': 'rohan', 'age': 45}
# <class 'dict'>

# %%
def people(**info):
    for i in info.keys():
        print(f"My {i} is {info[i]}")

people(name='rohan',age=45)
# Out:
# My name is rohan
# My age is 45

# %%
people(name='Kunal',height=5.9,weight=78)
# Out:
# My name is Kunal
# My height is 5.9
# My weight is 78

# %% [markdown]
# # Lambda function

# %%
disc = lambda amount,rate : amount*rate/100

# %%
disc(5600,6.89)
# Out:
# 385.84

# %%
# create a function sqr to find the square of a given number

# %%
# Write a function to clean a text for a proper name
# for ex = clean("  roHAN  ")   ->  "Rohan"
clean = lambda text : text.strip().title()

clean("  roHAN  ")
# Out:
# 'Rohan'

# %%
unclean_data = ["TIger  ", "MOHan  ","kunAL"]
list(map(clean,unclean_data))
# Out:
# ['Tiger', 'Mohan', 'Kunal']

# %% [markdown]
# # Recursion Function

# %%
def age(num):
    if num>=100:
        new_age = int(input("Enter a correct age"))
        age(new_age)
    else:
        print(f"Your age is {num}")

age(450)
# Out:
# Enter a correct age 900
# Enter a correct age 540
# Enter a correct age 120
# Enter a correct age 345
# Enter a correct age 45
# Your age is 45
