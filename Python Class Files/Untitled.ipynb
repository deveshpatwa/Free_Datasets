# %%
import myfunction

# %%
myfunction.total(45,87,12,3)
# Out:
# 147

# %%
myfunction.discount(67880,4.67)
# Out:
# 3169.9959999999996

# %%
myfunction

# %%
import myfunction as m

# %%
m.total(45,87,12)
# Out:
# 144

# %%
m.age
# Out:
# 45

# %%
m.name
# Out:
# 'rohan'

# %%
from myfunction import total

# %%
total(56,98,12)
# Out:
# 166

# %%
discount(899,23)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 discount(899,23)
#
# NameError: name 'discount' is not defined

# %%
t(45,87)
# Out:
# 132
