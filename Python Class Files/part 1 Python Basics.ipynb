# %% [markdown]
# # Variables
# - a variable is a name that you use to store data or a value in memory so that you can use
# it later in your program.
# - It acts like a container that holds some information
# - for example, a number, text, or list —
# - allows you to refer to that data by name instead of writing it directly every
# time.

# %%
45000 * 12 /100

# %%
amount = 38900
rate = 12 /100

print(amount * rate)

# %%
data = 300
print(data) 
data = 870
print(data)

# %%
aman = 300
rohan = 450
print(aman+rohan)

# %%
first name  = "rohan"

# %%
# delete a variable 
a = 10
print(a)
del a
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 print(a)
#       4 del a
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Rules for naming variables
# - Variable names can include letters(a-z,A-Z), numbers(0-9), and
# underscores (_).
# - They must start with a letter or underscore, not a number.
# - Variable names are case-sensitive (Name and name are different).
# - Don’t use Python keywords (like if, for, class, etc.) as variable names.

# %%
56hello = 90

# %%
for = 78

# %%
car = 90

# %%
# print simple interest using variables -  amount , year and interest rate?
# And then show compound interest of same

amount = 12900
interest_rate = 12.8/100
year = 3

print(amount * interest_rate * year)

# %% [markdown]
# # Arithmetic Operators

# %%
# + , - ,* , / , // , % , **
# BODMAS

# %%
45 + 6

# %% [markdown]
# ## floor division

# %%
print(10/3)
print(10//3)

# %% [markdown]
# ## Mod

# %%
print(10//3)
print(10%3)

# %%
print(17//7)
print(17%7)

# %%
# find if 56 is even or odd
print(55%2)

# %%
print(6%12)

# %% [markdown]
# ## Power **

# %%
print(5*2)
print(5**2)
print(5**3)

# %%
# find sqrt of 25

25 **(1/2)

# %% [markdown]
# # Data Types in python

# %%
a = 56
type(a)

# %%
a = 6.45
type(a)

# %%
a = "hello"
type(a)

# %%
a = 10/2
print(type(a))
print(a)

# %%
a = 10//2
print(type(a))
print(a)

# %%
a = [54,12,8,76]
print(type(a))
print(a)

# %%
45 > 5

# %%
a = True
type(a)

# %%
a = None
print(type(a))
print(a)

# %%
a = "None"
type(a)

# %%
a = 22j
type(a)

# %%
# what will happen if the data is not in its correct data type?

# %%
a = "15"
print(a+12)

# %%
a = "5"
print(a*3)

# %%
a = "hello "
print(a*4)

# %%
first = "Rohan"
last = "kumar"

print(first + last)
print("Mr."+first+ " " + last)

# %%
print(("hello "*2 +"bye ")*4)

# %% [markdown]
# # Input

# %%
# taking input from the user in runtime
# Input function will always take input as a string.

# %%
name = input()
print("Good Morning", name)

# %%
# take name and age using input function and print both
name = input("what is your name")
age = input("what is your age")

print("Your name is",name)
print("Your age is",age)

# %%
# take name from user('kunal') and print output - Hello Mr.Kunal

# %%
# Take two numbers from the user and Print there total 
num1 = input()
num2 = input()

print(num1+num2)

# %% [markdown]
# # Type casting

# %%
num1 = int(input())
num2 = int(input())

print(num1+num2)

# %%
num = float(input())
print(num)

# %%
int(6.43423)

# %%
str(876)

# %%
# print '5566'
a = 55
b = 66

# %%
# Write a Python program to add two numbers entered by the user.

# %%
# Write a program to calculate the square and cube of a number.

# %%
# Write a program to calculate the area of a rectangle (length × width).

# %%
# Write a program to calculate the area of a circle using radius = 7.

# %%
# Write a program to ﬁnd the average of three numbers.

# %%
# Write a program to convert temperature from Celsius to Fahrenheit.
# F = (C × 9/5) + 32

# %%
# Write a program to calculate the simple interest (use formula: SI = (P * R/100 * T)).

# %% [markdown]
# ![image.png](attachment:b2e9774e-b267-40d8-90f1-5c6a9e2c1c23.png)

# %%
# Write a program to calculate the compound interest.

# %%
# Write a program to ﬁnd the square root of a number using exponent operator (**).

# %%
# Write a program to ﬁnd the perimeter of a square and a rectangle.

# %%
# Write a program to swap two values.
a = 34
b = 76
print(a,b)
# code

print(a,b)   # 76 34

# %%
a , b = 50, 12.9

print(a)
print(b)

# %%
name,age,salary = "raohan",34,40000
print(name)
print(age)
print(salary)

# %%
a = 30
print(type(a))

a = "hello"
print(type(a))

# %% [markdown]
# # Assignment operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Update the value of A and add 5 to it?
a = 20
a = a+5

print(a)

# %%
# Update the value of A and add 5 to it?
a = 20
a += 5

print(a)

# %% [markdown]
# # Print Function

# %%
print("hello")

# %%
name = "Anil"
print("hello",name)

# %%
# F-string

name = "Anil"
age = 34

print("hello",name ,"Yor age is",age)
print("hello {name} Yor {age} is age")
print()
print(f"Hello {name} Your age is {age}")

# %%
# You are three years older than your friend 
friend = 32

# ans - " My age is 35 and my friend's age is 32"

# %%
name = "Rohan"
msg = f"Good morning {name}"

print(msg)

# %%
msg = f"Good morning {input("Enter you name")}"

print(msg)

# %%
sales = 6700
rate = 12/100

print(f"discount {rate*sales}")

# %%
# End

print("hello")
print("bye")

# %%
print("hello\nbye")

# %%
print("hello\tbye")

# %%
print('hello "Rohan" i\'m good')

# %%
# raw string
print(r"hello\nbye")

# %%
print("hello",end="--")
print("bye")

# %%
# sep
print("Rohan","Kumar")
print("Rohan","Kumar","how","are","you")
print("Rohan","Kumar","how","are","you",sep="-")
print("Rohan","Kumar","how","are","you",sep=", ")
print("Rohan","Kumar","how","are","you",sep="**")
